# %% [markdown]
# <a href="https://colab.research.google.com/github/TarrySingh/Tips-Tricks/blob/master/Vraag6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. **Leeftijd van het eerste huwelijk van de bruidegom en van de bruid door de jaren heen** (ik wil kijken of mensen jonger, later of onveranderd trouwen, hertrouwen valt hier buiten) - Tarry (JAARAKTE= jaar van trouwen, OPM1= leeftijd bruidegom, OPM2= leeftijd bruid, OPM3, OPM4 en OPM5 zijn notities. Echtscheidingen vaak afgekort tot es. weduwe en weduwenaar vaak afgekort tot Wd. en Wn.)
# 2. **Leeftijd bruidegom en bruid in verhouding tot beroep bruidegom en beroep vader van bruid** (trouwen mensen met een minder verdienstelijk beroep, zoals arbeiders jonger of later?) Nick (OPM1= leeftijd bruidegom en BEROEBG= beroep bruidegom, OPM2= leeftijd bruid en BERVABD= beroep vader van bruid)
#
# 3. **Leeftijdsverschil door de jaren heen** (hoe vaak komt het voor dat er een leeftijdsverschil van meer dan 5 én meer dan 10 jaar is, en in welk jaartal?) Tarry (OPM1= leeftijd bruidegom, OPM2= leeftijd bruid)

# %%
! pip install plotly==5.0.0
import plotly.express as px

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px
from scipy import stats

# set seaborn theme
sns.set_style(style="whitegrid")

# %%
pd.set_option('max_columns', None)
pd.set_option('max_colwidth', None)
pd.set_option("max_rows", None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Now, we can use pandas read_excel after installing the excel importer.
df = pd.read_excel('/content/drive/MyDrive/Nick/HUWadorp_1811_1934-Cleaned.xlsx')
df.head(10)

# %%
plt.rcParams["figure.figsize"] = [30, 18]
# Set up with a higher resolution screen (useful on Mac)
# %config InlineBackend.figure_format = 'retina'

# %%
sns.set_theme(style="whitegrid")
# JAARAKTE = sns.load_dataset("tips")
ax = sns.stripplot(x=df["JAARAKTE"])
# ax = sns.stripplot(x=df.BEROEBG, y=df.KlasseBG])

# %%
fig1 = px.violin(df, y=df["OPM1"])
fig2 = px.violin(df, y=df["OPM2"])
fig1.show()
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
'''
Leeftijd van het eerste huwelijk van de bruidegom en van de bruid door de jaren heen (ik wil kijken of mensen jonger, 
later of onveranderd trouwen, hertrouwen valt hier buiten) - Tarry (JAARAKTE= jaar van trouwen, 
OPM1= leeftijd bruidegom, OPM2= leeftijd bruid, OPM3, OPM4 en OPM5 zijn notities. 
Echtscheidingen vaak afgekort tot es. weduwe en weduwenaar vaak afgekort tot Wd. en Wn.)
'''
ax = sns.stripplot(x= df["JAARAKTE"], y=df["OPM1"], data=df)

# %%
ax = sns.stripplot(x= df["JAARAKTE"], y=df["OPM2"], data=df)

# %%
fig1 = px.scatter(x= df["JAARAKTE"], y=df["leefman"], color=df["BEROEBG"], width=2000, height=1200)

fig2 = px.scatter(x= df["JAARAKTE"], y=df["leefvrouw"], color=df["BEROEBD"], width=2000, height=1200)
fig1.show()
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(df, x = df['leefman'], y=df["leefvrouw"], width=1600, height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.violin(df, y= df["OPM2"], x=df["OPM1"], color= df["BEROEBD"], # color = df['BEROEBG']
                violinmode='overlay', # draw violins on top of each other
                # default violinmode is 'group' as in example above
                hover_data=df.columns, width=2000, height=1200)
fig.update_traces(marker=dict(size=12,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
